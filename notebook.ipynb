# %%
inventaire = {
    "bananes"      : 120,
    "mangues"      : 85,
    "ananas"       : 45,
    "noix de coco" : 60,
    "papayes"      : 30
}

# %%
def afficher_inventaire(invent):
    print("Inventaire actuel :")
    for fruit, quantite in invent.items():
        print(f"- {fruit.capitalize():<15} -- {quantite:>3} unités")

# %%
afficher_inventaire(inventaire)
# Out:
# Inventaire actuel :
# - Bananes         -- 120 unités
# - Mangues         --  85 unités
# - Ananas          --  45 unités
# - Noix de coco    --  60 unités
# - Papayes         --  30 unités

# %%
def recolter(invent, fruit, quantite):
    invent[fruit] = invent.get(fruit, 0) + quantite
    print(f"{fruit} récolté, {quantite} ajoutés à l'inventaire.")

# %%
def vendre(invent, fruit, quantite):
    vendus = min(invent.get(fruit, 0), quantite)
    invent[fruit] = max(invent.get(fruit, 0) - quantite, 0)
    print(f"{fruit} vendus, {vendus} sortis de l'inventaire.")

# %%
recolter(inventaire, "fruit de la passion", 25)
recolter(inventaire, "bananes", 10)
vendre(inventaire, "mangues", 15)
vendre(inventaire, "ananas", 70)
# Out:
# fruit de la passion récolté, 25 ajoutés à l'inventaire
# bananes récolté, 10 ajoutés à l'inventaire
# mangues vendus, 15 sortis de l'inventaire.
# ananas vendus, 45 sortis de l'inventaire.

# %%
afficher_inventaire(inventaire)
# Out:
# Inventaire actuel :
# - Bananes         -- 130 unités
# - Mangues         --  70 unités
# - Ananas          --   0 unités
# - Noix de coco    --  60 unités
# - Papayes         --  30 unités
# - Fruit de la passion --  25 unités

# %%
import json
with open("data/inventaire.json", "w", encoding="utf-8") as fichier:
    json.dump(inventaire, fichier, ensure_ascii=False, indent=4)
